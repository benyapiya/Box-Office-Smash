# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(user="cohort17",
                            password="Cohort17Movies",
                            host="moviesdb.ce8d6g1pa5lm.us-east-1.rds.amazonaws.com",
                            port="5432",database="moviesdb")

    dbquery = "select * from movies_analytical_table"
    
    df = pd.read_sql_query(dbquery, conn)

except (Exception, psycopg2.Error) as error :
    print ("Error while fetching data from PostgreSQL", error)

finally:
    if(conn):
        conn.close()

# %%
df.head()
# Out:
#         id     tconst titletype    primarytitle  originaltitle region  \
# 0  4636872  tt6608094     movie               &              &     US
# 1  3738840  tt4602074     movie    001 Trolling       Trolling     US
# 2  2495237  tt2078523     movie  009 Re: Cyborg  009 Re:Cyborg     US
# 3  2014800  tt1578696     movie         0:22:43        0:22:43     US
# 4  2363436  tt1942127     movie           02543          02543     US
#
#    isadult  startyear endyear  runtimeminutes  ... keyword28 keyword29  \
# 0        0       2017    None             NaN  ...      None      None
# 1        0       2017    None            80.0  ...      None      None
# 2        0       2012    None           103.0  ...      None      None
# 3        0       2010    None            62.0  ...      None      None
# 4        0       2010    None            15.0  ...      None      None
#
#   keyword30 keyword31 studio releasedate lifetime_gross productionbudget  \
# 0      None      None   None        None            NaN              NaN
# 1      None      None   None        None            NaN              NaN
# 2      None      None   None        None            NaN              NaN
# 3      None      None   None        None            NaN              NaN
# 4      None      None   None        None            NaN              NaN
#
#   domesticgross worldwidegross
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# [5 rows x 77 columns]
